# %% [markdown]
# # Binary Classification Demo
#
# This notebook shows how to generate data, train a model, and evaluate it.

# %%
# install dependencies if not already done
# !pip install -r ../requirements.txt

# %%
from src.binary_classification import data, model

X, y = data.generate_dataset(n_samples=500, n_features=10)
print(X.head())

clf, acc = model.train(output_path="demo_model.joblib", n_samples=500, n_features=10)
print('accuracy =', acc)
